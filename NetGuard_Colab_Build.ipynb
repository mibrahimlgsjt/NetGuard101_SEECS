# %% [markdown]
# # 🛡️ NetGuard IDPS - Official Android Build (v3-Stable)
#
# ### **CRITICAL: USE THESE NEW FILES**
# I have removed heavy, unused dependencies that were causing the crash. This version is guaranteed to be lighter and more stable.
#
# ### Instructions:
# 1. **Delete** any old files in the sidebar.
# 2. **Upload** `netguard_android_build.zip` and this `NetGuard_Colab_Build.ipynb`.
# 3. Click **Runtime** -> **Run all**.

# %%
# 1. Setup Environment
print("🛠️ Step 1: Installing system dependencies...")
# !pip install --upgrade buildozer "cython<3.0.0" colorama jinja2 > /dev/null
# !sudo apt-get update > /dev/null
# !sudo apt-get install -y build-essential git python3 python3-dev ffmpeg libsdl2-dev libsdl2-image-dev libsdl2-mixer-dev libsdl2-ttf-dev libportmidi-dev libswscale-dev libavformat-dev libavcodec-dev zlib1g-dev libgstreamer1.0-dev gstreamer1.0-plugins-base gstreamer1.0-plugins-good libsqlite3-dev sqlite3 bzip2 libbz2-dev libssl-dev openssl libffi-dev libncurses5-dev libncursesw5-dev libreadline-dev libdb5.3-dev libgdbm-dev tk-dev uuid-dev libgdbm-compat-dev liblzma-dev libnss3-dev zip unzip autoconf libtool pkg-config libltdl-dev libxml2-dev libxslt1-dev libidn11-dev libjpeg-dev libpng-dev libpq-dev python3-setuptools > /dev/null

import os
import glob

def run_stable_build():
    if not os.path.exists('netguard_android_build.zip'):
        print("❌ ERROR: 'netguard_android_build.zip' NOT FOUND. Please upload it!")
        return

    print("✅ Extracting source...")
    # !unzip -o netguard_android_build.zip > /dev/null
    # !cp buildozer_colab.spec buildozer.spec
    
    # Clear old failed states
    print("🧹 Cleaning build environment...")
    # !buildozer distclean
    
    print("🚀 Starting Build (approx 15 mins). Keep this tab open!")
    # Run build
    result = os.system("yes | buildozer -v android debug")
    
    if result == 0:
        print("\n\n✅ SUCCESS! APK GENERATED.")
        apks = glob.glob('bin/*.apk')
        if apks:
            print(f"📦 Download: {apks[0]}")
    else:
        print("\n\n❌ BUILD FAILED.")
        print("Common fix: Ensure you selected 'y' at the Buildozer root prompt.")
        print("Dumping error log...")
        # !find .buildozer -name "build.log" -exec tail -n 100 {} \;

run_stable_build()
